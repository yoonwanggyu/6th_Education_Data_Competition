# %%
import pandas as pd
# Out:
# c:\Users\chldy\anaconda3\envs\torch\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
df_b= pd.read_excel('C:/Users/chldy/OneDrive/바탕 화면/용용/딥러닝 부트캠프/교육데이터공모전/2023년 하반기 유초중등 학교별 학년별 학생수 학급수 교원 직원_240221.xlsx',sheet_name='학교별 주요 통계', header=12, usecols='A:CV')
df_a= pd.read_excel('C:/Users/chldy/Downloads/2023년 유초중등 학교별 학년별 학생수 학급수 입학 졸업 교원 직원 면적_240319 (1).xlsx',sheet_name='학교별 주요통계', header=14, usecols='A:ER')
df_comb= pd.read_excel('C:/Users/chldy/Downloads/final_df.xlsx')

# %%
comb_list= df_comb['학교명'].to_list()

# %%
df_ex_comb= df_b[~df_b['학교명'].isin(comb_list)]

# %%
df_ex_comb # 통합학교 뺌
# Out:
#           조사기준일  시도   행정구 교육\n(지원)청   학교급 고등학교\n유형 운영상특례 학교\n세부유형  \
# 0      20231001  서울   성북구       서울시  고등학교      일반고  해당없음   일반고등학교
# 1      20231001  서울   송파구       서울시  고등학교      일반고  해당없음   일반고등학교
# 2      20231001  서울   강남구       서울시  고등학교      일반고  해당없음   일반고등학교
# 3      20231001  서울   강남구       서울시  고등학교      일반고  해당없음   일반고등학교
# 4      20231001  서울   성북구       서울시  고등학교      일반고  해당없음   일반고등학교
# ...         ...  ..   ...       ...   ...      ...   ...      ...
# 20738  20231001  제주  서귀포시      서귀포시   중학교      NaN  해당없음    일반중학교
# 20739  20231001  제주  서귀포시      서귀포시   중학교      NaN  해당없음    일반중학교
# 20740  20231001  제주  서귀포시      서귀포시   중학교      NaN  해당없음    일반중학교
# 20741  20231001  제주  서귀포시      서귀포시   중학교      NaN  해당없음    일반중학교
# 20742  20231001  제주  서귀포시      서귀포시   중학교      NaN  해당없음    일반중학교
#
#                    학교명 본분교  ... 교원수_기간제_계 교원수_기간제_남 교원수_기간제_여 교원1인당 학생수  \
# 0      서울대학교사범대학부설고등학교  본교  ...        17         8         9       9.8
# 1               가락고등학교  본교  ...        15         5        10      10.9
# 2               개포고등학교  본교  ...        13         3        10      10.2
# 3               경기고등학교  본교  ...        14         4        10      11.7
# 4               경동고등학교  본교  ...         9         3         6       9.2
# ...                ...  ..  ...       ...       ...       ...       ...
# 20738            위미중학교  본교  ...         4         3         1       6.5
# 20739            중문중학교  본교  ...         3         1         2      11.0
# 20740            표선중학교  본교  ...         4         1         3      10.9
# 20741            효돈중학교  본교  ...         2         1         1       7.5
# 20742            남주중학교  본교  ...         3         1         2      14.5
#
#       전체직원_계 전체직원_남  전체직원_여 정규직원_계 정규직원_남 정규직원_여
# 0         16      2      14      4      1      3
# 1         10      2       8      4      1      3
# 2         11      2       9      5      1      4
# 3         15      7       8      6      4      2
# 4         14      4      10      4      1      3
# ...      ...    ...     ...    ...    ...    ...
# 20738      8      1       7      3      1      2
# 20739     13      2      11      4      2      2
# 20740     15      5      10      5      3      2
# 20741      8      0       8      3      0      3
# 20742      7      3       4      4      3      1
#
# [20394 rows x 100 columns]

# %%
df_elementary= df_ex_comb[(df_ex_comb['시도']=='인천')&(df_ex_comb['학교급']=='초등학교')] #통합학교 뺀 데이터 중 인천 초, 중, 고 (교지 면적 없음) 하반기
df_middle= df_ex_comb[(df_ex_comb['시도']=='인천')&(df_ex_comb['학교급']=='중학교')]
df_high= df_ex_comb[(df_ex_comb['시도']=='인천')&(df_ex_comb['학교급']=='고등학교')]

# %%
df_aa_ele= df_a[(df_a['시도']=='인천')&(df_a['학교급']=='초등학교')] #통합학교 있는 교지 면적 o
df_aa_mid= df_a[(df_a['시도']=='인천')&(df_a['학교급']=='중학교')]
df_aa_hig= df_a[(df_a['시도']=='인천')&(df_a['학교급']=='고등학교')]

# %%
df_elementary
# Out:
#          조사기준일  시도   행정구 교육\n(지원)청   학교급 고등학교\n유형 운영상특례 학교\n세부유형  \
# 4197  20231001  인천  미추홀구        남부  초등학교      NaN  해당없음     초등학교
# 4198  20231001  인천   옹진군        남부  초등학교      NaN  해당없음     초등학교
# 4199  20231001  인천   옹진군        남부  초등학교      NaN  해당없음     초등학교
# 4200  20231001  인천    중구        남부  초등학교      NaN  해당없음     초등학교
# 4201  20231001  인천  미추홀구        남부  초등학교      NaN  해당없음     초등학교
# ...        ...  ..   ...       ...   ...      ...   ...      ...
# 4910  20231001  인천   강화군        강화  초등학교      NaN  해당없음     초등학교
# 4911  20231001  인천   강화군        강화  초등학교      NaN  해당없음     초등학교
# 4912  20231001  인천   강화군        강화  초등학교      NaN  해당없음     초등학교
# 4913  20231001  인천   강화군        강화  초등학교      NaN  해당없음     초등학교
# 4914  20231001  인천   강화군        강화  초등학교      NaN  해당없음     초등학교
#
#                 학교명  본분교  ... 교원수_기간제_계 교원수_기간제_남 교원수_기간제_여 교원1인당 학생수 전체직원_계  \
# 4197       인천용학초등학교   본교  ...         5         1         4      16.9     23
# 4198  인천남부초등학교이작분교장  분교장  ...         0         0         0       3.0      0
# 4199    대청초등학교소청분교장  분교장  ...         0         0         0       NaN      0
# 4200       인천공항초등학교   본교  ...         5         1         4      13.7     20
# 4201       인천관교초등학교   본교  ...         1         1         0      15.0     20
# ...             ...  ...  ...       ...       ...       ...       ...    ...
# 4910         조산초등학교   본교  ...         3         1         2       3.1      8
# 4911         하점초등학교   본교  ...         2         0         2       3.5     10
# 4912         합일초등학교   본교  ...         1         0         1       7.6     16
# 4913         해명초등학교   본교  ...         0         0         0       1.3      7
# 4914         화도초등학교   본교  ...         2         0         2       4.7     10
#
#      전체직원_남  전체직원_여 정규직원_계 정규직원_남 정규직원_여
# 4197      2      21      4      0      4
# 4198      0       0      0      0      0
# 4199      0       0      0      0      0
# 4200      4      16      5      3      2
# 4201      2      18      4      0      4
# ...     ...     ...    ...    ...    ...
# 4910      0       8      2      0      2
# 4911      3       7      3      1      2
# 4912      2      14      4      0      4
# 4913      2       5      2      1      1
# 4914      2       8      2      1      1
#
# [268 rows x 100 columns]

# %%
df_aa= df_aa_ele[['학교명', '전체직원_계','일반\n교실','교과\n교실','특별\n교실','수준별교실','기타\n교실','교지면적','학생\n1인당\n교지면적']] #교지 면적 o, 상반기
df_bb= df_aa_mid[['학교명', '전체직원_계','일반\n교실','교과\n교실','특별\n교실','수준별교실','기타\n교실','교지면적','학생\n1인당\n교지면적']]
df_cc= df_aa_hig[['학교명', '전체직원_계','일반\n교실','교과\n교실','특별\n교실','수준별교실','기타\n교실','교지면적','학생\n1인당\n교지면적']]

# %%
df_aa
# Out:
#                 학교명  전체직원_계  일반\n교실  교과\n교실  특별\n교실  수준별교실  기타\n교실   교지면적  \
# 4227         덕적초등학교       3       5       0       0      0       0      0
# 4228       인천용학초등학교      23      47       1       4      1       8  11000
# 4229  인천남부초등학교이작분교장       0       2       1       1      0       0   3905
# 4230    대청초등학교소청분교장       0       2       0       0      0       0   9428
# 4231       인천공항초등학교      19      24       0       6      0      17  11635
# ...             ...     ...     ...     ...     ...    ...     ...    ...
# 4947    교동초등학교지석분교장       0       0       0       0      0       0      0
# 4948         하점초등학교       9       8       0       5      0       0  13304
# 4949         합일초등학교      16      12       0       4      0       2   6963
# 4950         해명초등학교       7       5       0       4      0       4  11271
# 4951         화도초등학교      10       6       1       2      0       0  14275
#
#       학생\n1인당\n교지면적
# 4227            0.0
# 4228            9.4
# 4229          433.9
# 4230            0.0
# 4231           23.6
# ...             ...
# 4947            0.0
# 4948          295.6
# 4949           46.4
# 4950          593.2
# 4951          209.9
#
# [272 rows x 9 columns]

# %%
merge_df_elementary= pd.merge(df_elementary, df_aa,how='inner',on='학교명')
merge_df_middle= pd.merge(df_middle, df_bb,how='inner',on='학교명')
merge_df_high= pd.merge(df_high, df_cc,how='inner',on='학교명')

# %%
merge_df_elementary
# Out:
#         조사기준일  시도   행정구 교육\n(지원)청   학교급 고등학교\n유형 운영상특례 학교\n세부유형  \
# 0    20231001  인천  미추홀구        남부  초등학교      NaN  해당없음     초등학교
# 1    20231001  인천   옹진군        남부  초등학교      NaN  해당없음     초등학교
# 2    20231001  인천   옹진군        남부  초등학교      NaN  해당없음     초등학교
# 3    20231001  인천    중구        남부  초등학교      NaN  해당없음     초등학교
# 4    20231001  인천  미추홀구        남부  초등학교      NaN  해당없음     초등학교
# ..        ...  ..   ...       ...   ...      ...   ...      ...
# 261  20231001  인천   강화군        강화  초등학교      NaN  해당없음     초등학교
# 262  20231001  인천   강화군        강화  초등학교      NaN  해당없음     초등학교
# 263  20231001  인천   강화군        강화  초등학교      NaN  해당없음     초등학교
# 264  20231001  인천   강화군        강화  초등학교      NaN  해당없음     초등학교
# 265  20231001  인천   강화군        강화  초등학교      NaN  해당없음     초등학교
#
#                학교명  본분교  ... 정규직원_남 정규직원_여 전체직원_계_y 일반\n교실 교과\n교실 특별\n교실  \
# 0         인천용학초등학교   본교  ...      0      4       23     47      1      4
# 1    인천남부초등학교이작분교장  분교장  ...      0      0        0      2      1      1
# 2      대청초등학교소청분교장  분교장  ...      0      0        0      2      0      0
# 3         인천공항초등학교   본교  ...      3      2       19     24      0      6
# 4         인천관교초등학교   본교  ...      0      4       19     28      0      4
# ..             ...  ...  ...    ...    ...      ...    ...    ...    ...
# 261         조산초등학교   본교  ...      0      2        8      7      0      1
# 262         하점초등학교   본교  ...      1      2        9      8      0      5
# 263         합일초등학교   본교  ...      0      4       16     12      0      4
# 264         해명초등학교   본교  ...      1      1        7      5      0      4
# 265         화도초등학교   본교  ...      1      1       10      6      1      2
#
#      수준별교실 기타\n교실   교지면적 학생\n1인당\n교지면적
# 0        1      8  11000           9.4
# 1        0      0   3905         433.9
# 2        0      0   9428           0.0
# 3        0     17  11635          23.6
# 4        0      0  12563          21.8
# ..     ...    ...    ...           ...
# 261      0      1  13482         299.6
# 262      0      0  13304         295.6
# 263      0      2   6963          46.4
# 264      0      4  11271         593.2
# 265      0      0  14275         209.9
#
# [266 rows x 108 columns]

# %%
merge_df_elementary.to_csv('incheon_elementary.csv')
merge_df_middle.to_csv('incheon_middle.csv')
merge_df_high.to_csv('incheon_high.csv')

# %% [markdown]
# ### 여기부터 쓰면됨

# %%
import pandas as pd
df= pd.read_csv('C:/Users/chldy/OneDrive/바탕 화면/용용/딥러닝 부트캠프/교육데이터공모전/incheon_elementary_code.csv')

# %%
df.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
df_2= pd.read_csv('C:/Users/chldy/OneDrive/바탕 화면/용용/딥러닝 부트캠프/교육데이터공모전/incheon_all.csv',encoding='cp949')

# %%
df_aca= pd.read_csv('C:/Users/chldy/OneDrive/바탕 화면/용용/딥러닝 부트캠프/교육데이터공모전/동별학원수.csv')

# %%
df_aca.drop(['Unnamed: 0'],axis=1, inplace=True)

# %%
df_2
# Out:
#        EMD_CD SIDO_NM SGG_NM EMD_NM  TOT_NMPR_C
# 0    28110151     인천광     중구    덕교동         570
# 1    28110150     인천광     중구    남북동         836
# 2    28110128     인천광     중구  신흥동3가        6400
# 3    28110101     인천광     중구  중앙동1가          73
# 4    28110102     인천광     중구  중앙동2가          68
# ..        ...     ...    ...    ...         ...
# 151  28260115     인천광     서구    원당동       44891
# 152  28260104     인천광     서구    경서동       12925
# 153  28260118     인천광     서구    금곡동        4500
# 154  28260119     인천광     서구    오류동        5388
# 155  28260113     인천광     서구    마전동       49720
#
# [156 rows x 5 columns]

# %%
df_aca.columns= ['EMD_NM','학원수']

# %%
df_3= pd.merge(df_2, df_aca, how='outer',on='EMD_NM')

# %%
df_3=df_3.fillna(0)

# %%
df_3=df_3[['EMD_CD','SGG_NM','EMD_NM','TOT_NMPR_C','학원수']]
df_3.columns=['법정동코드','구단위','동이름','전체인구수','학원수']

# %%
df_3
# Out:
#         법정동코드  구단위    동이름  전체인구수    학원수
# 0    28260108   서구    가정동  65740  137.0
# 1    28260112   서구    가좌동  58350   71.0
# 2    28200102  남동구    간석동  92480  156.0
# 3    28237106  부평구    갈산동  32684   41.0
# 4    28245119  계양구    갈현동    136    0.0
# ..        ...  ...    ...    ...    ...
# 151  28110108   중구  해안동4가     16    0.0
# 152  28710340  강화군    화도면   4550    1.0
# 153  28140102   동구    화수동   6835    7.0
# 154  28140104   동구    화평동   1776    0.0
# 155  28245101  계양구    효성동  54692   82.0
#
# [156 rows x 5 columns]

# %%
pd.options.display.max_columns = 20

# %%
df_final= pd.merge(df, df_3,how='inner',on='법정동코드')

# %%
df_final= df_final.fillna(0)

# %%
df_final
# Out:
#         조사기준일  시도   행정구 교육\n(지원)청   학교급  고등학교\n유형 운영상특례 학교\n세부유형  \
# 0    20231001  인천  미추홀구        남부  초등학교       0.0  해당없음     초등학교
# 1    20231001  인천   옹진군        남부  초등학교       0.0  해당없음     초등학교
# 2    20231001  인천   옹진군        남부  초등학교       0.0  해당없음     초등학교
# 3    20231001  인천    중구        남부  초등학교       0.0  해당없음     초등학교
# 4    20231001  인천  미추홀구        남부  초등학교       0.0  해당없음     초등학교
# ..        ...  ..   ...       ...   ...       ...   ...      ...
# 261  20231001  인천   강화군        강화  초등학교       0.0  해당없음     초등학교
# 262  20231001  인천   강화군        강화  초등학교       0.0  해당없음     초등학교
# 263  20231001  인천   강화군        강화  초등학교       0.0  해당없음     초등학교
# 264  20231001  인천   강화군        강화  초등학교       0.0  해당없음     초등학교
# 265  20231001  인천   강화군        강화  초등학교       0.0  해당없음     초등학교
#
#                학교명  본분교  ... 기타\n교실   교지면적  학생\n1인당\n교지면적         lat  \
# 0         인천용학초등학교   본교  ...      8  11000            9.4  126.643269
# 1    인천남부초등학교이작분교장  분교장  ...      0   3905          433.9  126.252760
# 2      대청초등학교소청분교장  분교장  ...      0   9428            0.0  124.750860
# 3         인천공항초등학교   본교  ...     17  11635           23.6  126.486001
# 4         인천관교초등학교   본교  ...      0  12563           21.8  126.692719
# ..             ...  ...  ...    ...    ...            ...         ...
# 261         조산초등학교   본교  ...      1  13482          299.6  126.438362
# 262         하점초등학교   본교  ...      0  13304          295.6  126.414187
# 263         합일초등학교   본교  ...      2   6963           46.4  126.482806
# 264         해명초등학교   본교  ...      4  11271          593.2  126.362707
# 265         화도초등학교   본교  ...      0  14275          209.9  126.418767
#
#            lon     법정동코드   구단위  동이름  전체인구수    학원수
# 0    37.446686  28177102  미추홀구  용현동  87932  176.0
# 1    37.176762  28720370   옹진군  자월면   1358    0.0
# 2    37.773776  28720340   옹진군  대청면   1434    0.0
# 3    37.491863  28110147    중구  운서동  36515   48.0
# 4    37.446234  28177106  미추홀구  관교동  14384   35.0
# ..         ...       ...   ...  ...    ...    ...
# 261  37.653315  28710350   강화군  양도면   4213    0.0
# 262  37.773692  28710370   강화군  하점면   4009    0.0
# 263  37.744285  28710250   강화군  강화읍  22356   54.0
# 264  37.668700  28710410   강화군  삼산면   2116    0.0
# 265  37.631868  28710340   강화군  화도면   4550    1.0
#
# [266 rows x 115 columns]

# %%
df_final_name=df_final[['법정동코드','동이름']]

# %% [markdown]
# z
# - 학생 인구 비율
# - 교원 수
# - 교원 당 학생 수
# - 총 면적
# - 1인 평균 면적
# - 총 학급 수
# - 평균 학급 수
# - 학급 당 학생 수
# - 학원수
# - 학교 수**(종속)**

# %%
elementary_dong= df_final.groupby('법정동코드').agg({
    '학생수_총계_계':'sum',
    '전체인구수':'mean',
    '교원수_총계_계':'sum',
    '편성학급수_계':'sum',
    '학급당\n 학생수':'sum',
    '교원1인당 학생수':'sum',
    '전체직원_계_x':'sum',
    '교지면적':'sum',
    '학생\n1인당\n교지면적':'sum',
    '학원수':'sum',
    '정규직원_계':'count'
})

# %%
elementary_dong
# Out:
#           학생수_총계_계   전체인구수  교원수_총계_계  편성학급수_계  학급당\n 학생수  교원1인당 학생수  전체직원_계_x  \
# 법정동코드
# 28110118       135  5445.0        18       12       11.3        7.5        11
# 28110120       489   238.0        20       18       27.2       24.5         9
# 28110125       387  1241.0        36       24       16.1       10.8        19
# 28110128      1046  6400.0        70       52       39.4       29.2        41
# 28110137       195  2062.0        24       14       13.9        8.1        14
# ...            ...     ...       ...      ...        ...        ...       ...
# 28720310        21  2134.0         7        7        5.8        5.8         4
# 28720330       159  4903.0        26       14       22.3       12.0        17
# 28720340        22  1434.0         6        5        4.4        3.7         3
# 28720360       195  6567.0        19       13       15.0       10.3         9
# 28720370        15  1358.0         6        6        5.0        5.0         0
#
#            교지면적  학생\n1인당\n교지면적   학원수  정규직원_계
# 법정동코드
# 28110118  11582           82.1   6.0       1
# 28110120   2242            4.5   0.0       1
# 28110125  15683           40.2  11.0       1
# 28110128  23531           52.2  14.0       2
# 28110137  21253          109.6   1.0       1
# ...         ...            ...   ...     ...
# 28720310  16966         1739.0   0.0       2
# 28720330  29114          396.7   4.0       2
# 28720340  20769          515.5   0.0       2
# 28720360  19583           96.5   3.0       1
# 28720370  22087         2560.2   0.0       3
#
# [89 rows x 11 columns]

# %%
elementary_dong.columns= ['총학생수','전체인구수','교원수총계','학급수총계','학급당학생수','교원당학생수','전체직원수','교지면적','학생1인당교지면적','학원수','학교수']

# %%
elementary_dong['법정동코드']=elementary_dong.index.to_list()
elementary_dong_new= elementary_dong.reset_index(drop=True)

# %%
elementary_dong_new['인구수대비학생수']= elementary_dong_new['총학생수']/elementary_dong_new['전체인구수']
elementary_dong_new
# Out:
#     총학생수   전체인구수  교원수총계  학급수총계  학급당학생수  교원당학생수  전체직원수   교지면적  학생1인당교지면적   학원수  \
# 0    135  5445.0     18     12    11.3     7.5     11  11582       82.1   6.0
# 1    489   238.0     20     18    27.2    24.5      9   2242        4.5   0.0
# 2    387  1241.0     36     24    16.1    10.8     19  15683       40.2  11.0
# 3   1046  6400.0     70     52    39.4    29.2     41  23531       52.2  14.0
# 4    195  2062.0     24     14    13.9     8.1     14  21253      109.6   1.0
# ..   ...     ...    ...    ...     ...     ...    ...    ...        ...   ...
# 84    21  2134.0      7      7     5.8     5.8      4  16966     1739.0   0.0
# 85   159  4903.0     26     14    22.3    12.0     17  29114      396.7   4.0
# 86    22  1434.0      6      5     4.4     3.7      3  20769      515.5   0.0
# 87   195  6567.0     19     13    15.0    10.3      9  19583       96.5   3.0
# 88    15  1358.0      6      6     5.0     5.0      0  22087     2560.2   0.0
#
#     학교수     법정동코드  인구수대비학생수
# 0     1  28110118  0.024793
# 1     1  28110120  2.054622
# 2     1  28110125  0.311845
# 3     2  28110128  0.163438
# 4     1  28110137  0.094568
# ..  ...       ...       ...
# 84    2  28720310  0.009841
# 85    2  28720330  0.032429
# 86    2  28720340  0.015342
# 87    1  28720360  0.029694
# 88    3  28720370  0.011046
#
# [89 rows x 13 columns]

# %%
df_final_name
# Out:
#         법정동코드  동이름
# 0    28177102  용현동
# 1    28720370  자월면
# 2    28720340  대청면
# 3    28110147  운서동
# 4    28177106  관교동
# ..        ...  ...
# 261  28710350  양도면
# 262  28710370  하점면
# 263  28710250  강화읍
# 264  28710410  삼산면
# 265  28710340  화도면
#
# [266 rows x 2 columns]

# %%
elementary_dong_new.to_csv('elementary_final.csv')

# %%
pwd
# Out:
# 'c:\\Users\\chldy\\OneDrive\\바탕 화면\\용용\\딥러닝 부트캠프\\교육데이터공모전'

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
import matplotlib.pyplot as plt
from statsmodels.formula.api import ols
from mpl_toolkits.mplot3d import Axes3D
from sklearn import linear_model

variables = ['총학생수','전체인구수','교원수총계','학급수총계','학급당학생수','교원당학생수','전체직원수','교지면적','학생1인당교지면적','학원수','인구수대비학생수']   # 설명 변수 리스트

y = elementary_dong_new['학교수']   # 반응 변수
selected_variables = variables   # 초기에는 모든 변수가 선택된 상태
sl_remove = 0.05
 
sv_per_step = []   # 각 스텝별로 선택된 변수들
adjusted_r_squared = []   # 각 스텝별 수정된 결정계수
steps = []   # 스텝
step = 0

# %%
while len(selected_variables) > 0:
    X = sm.add_constant(elementary_dong_new[selected_variables])
    p_vals = sm.OLS(y,X).fit().pvalues[1:]   # 절편항의 p-value는 제외
    max_pval = p_vals.max()   # 최대 p-value
    if max_pval >= sl_remove:   # 최대 p-value값이 기준값보다 크거나 같으면 제외
        remove_variable = p_vals.idxmax()
        selected_variables.remove(remove_variable)
 
        step += 1
        steps.append(step)
        adj_r_squared = sm.OLS(y,sm.add_constant(elementary_dong_new[selected_variables])).fit().rsquared_adj
        adjusted_r_squared.append(adj_r_squared)
        sv_per_step.append(selected_variables.copy())
    else:
        break

# %%
selected_variables
# Out:
# ['총학생수', '전체인구수', '학급수총계', '학급당학생수', '교원당학생수', '학생1인당교지면적', '학원수']

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
fig = plt.figure(figsize=(10,10))
fig.set_facecolor('white')
 
font_size = 15
plt.xticks(steps,[f'step {s}\n'+'\n'.join(sv_per_step[i]) for i,s in enumerate(steps)], fontsize=12)
plt.plot(steps,adjusted_r_squared, marker='o')
    
plt.ylabel('Adjusted R Squared',fontsize=font_size)
plt.grid(True)
plt.show()

# %%
x_data = elementary_dong_new[['총학생수', '전체인구수', '학급수총계', '학급당학생수', '교원당학생수', '학생1인당교지면적', '학원수']]
# x_data = sm.add_constant(x_data)
target = elementary_dong_new[['학교수']]

multi_model = sm.OLS(target, x_data)
fitted_multi_model = multi_model.fit()
fitted_multi_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                    학교수   R-squared (uncentered):                   0.997
# Model:                            OLS   Adj. R-squared (uncentered):              0.997
# Method:                 Least Squares   F-statistic:                              4320.
# Date:                Thu, 09 May 2024   Prob (F-statistic):                   1.84e-102
# Time:                        15:45:27   Log-Likelihood:                          14.347
# No. Observations:                  89   AIC:                                     -14.69
# Df Residuals:                      82   BIC:                                      2.727
# Df Model:                           7
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# 총학생수          -0.0016      0.000    -11.062      0.000      -0.002      -0.001
# 전체인구수      -5.621e-06   2.09e-06     -2.692      0.009   -9.78e-06   -1.47e-06
# 학급수총계          0.0412      0.004      9.633      0.000       0.033       0.050
# 학급당학생수         0.0692      0.008      8.219      0.000       0.052       0.086
# 교원당학생수        -0.0393      0.012     -3.237      0.002      -0.063      -0.015
# 학생1인당교지면적      0.0011   6.12e-05     18.219      0.000       0.001       0.001
# 학원수         4.698e-05   3.73e-05      1.261      0.211   -2.71e-05       0.000
# ==============================================================================
# Omnibus:                       67.384   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              402.246
# Skew:                           2.380   Prob(JB):                     4.50e-88
# Kurtosis:                      12.263   Cond. No.                     3.26e+04
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 3.26e+04. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
from sklearn.preprocessing import StandardScaler
x = StandardScaler().fit_transform(x_data)
features=['총학생수', '전체인구수', '학급수총계', '학급당학생수', '교원당학생수', '학생1인당교지면적', '학원수']
pd.DataFrame(x,columns=features)
# Out:
#         총학생수     전체인구수     학급수총계    학급당학생수    교원당학생수  학생1인당교지면적       학원수
# 0  -0.683528 -0.711514 -0.709000 -0.755379 -0.751041  -0.306492 -0.321110
# 1  -0.531280 -0.847758 -0.647126 -0.493089 -0.360121  -0.524565 -0.325373
# 2  -0.575148 -0.821514 -0.585253 -0.676197 -0.675156  -0.424240 -0.317557
# 3  -0.291725 -0.686526 -0.296508 -0.291835 -0.252044  -0.390517 -0.315426
# 4  -0.657723 -0.800032 -0.688376 -0.712489 -0.737244  -0.229210 -0.324662
# ..       ...       ...       ...       ...       ...        ...       ...
# 84 -0.732557 -0.798148 -0.760562 -0.846109 -0.790133   4.349773 -0.325373
# 85 -0.673206 -0.725696 -0.688376 -0.573921 -0.647562   0.577606 -0.322531
# 86 -0.732127 -0.816464 -0.781187 -0.869203 -0.838423   0.911461 -0.325373
# 87 -0.657723 -0.682157 -0.698688 -0.694343 -0.686654  -0.266024 -0.323241
# 88 -0.735138 -0.818452 -0.770874 -0.859306 -0.808529   6.657531 -0.325373
#
# [89 rows x 7 columns]

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=1)   # 주성분을 몇개로 할지 결정
printcipalComponents = pca.fit_transform(x)
principalDf = pd.DataFrame(data=printcipalComponents, columns = ['principal component1'])

# %%
principalDf
# Out:
#     principal component1
# 0              -1.598559
# 1              -1.280643
# 2              -1.472483
# 3              -0.843192
# 4              -1.596033
# ..                   ...
# 84             -1.978432
# 85             -1.520105
# 86             -1.841123
# 87             -1.522470
# 88             -2.127801
#
# [89 rows x 1 columns]

# %%
principalDf['행정동코드']=elementary_dong_new['법정동코드']
principalDf['학교수']=elementary_dong_new['학교수']

# %%
principalDf
# Out:
#        pca_x     행정동코드  학교개수
# 0  -1.598559  28110118     1
# 1  -1.280643  28110120     1
# 2  -1.472483  28110125     1
# 3  -0.843192  28110128     2
# 4  -1.596033  28110137     1
# ..       ...       ...   ...
# 84 -1.978432  28720310     2
# 85 -1.520105  28720330     2
# 86 -1.841123  28720340     2
# 87 -1.522470  28720360     1
# 88 -2.127801  28720370     3
#
# [89 rows x 3 columns]

# %%
principalDf.columns=['pca_x', '행정동코드', '학교개수']

# %%
principalDf
# Out:
#        pca_x     행정동코드  학교개수
# 0  -1.598559  28110118     1
# 1  -1.280643  28110120     1
# 2  -1.472483  28110125     1
# 3  -0.843192  28110128     2
# 4  -1.596033  28110137     1
# ..       ...       ...   ...
# 84 -1.978432  28720310     2
# 85 -1.520105  28720330     2
# 86 -1.841123  28720340     2
# 87 -1.522470  28720360     1
# 88 -2.127801  28720370     3
#
# [89 rows x 3 columns]

# %%
x = principalDf['pca_x']
y = principalDf['학교개수']

# %%
from sklearn.linear_model import LinearRegression
line_fitter = LinearRegression()
line_fitter.fit(x.values.reshape(-1,1), y)
# Out:
# LinearRegression()

# %%
plt.plot(x, y, 'o')
plt.plot(x,line_fitter.predict(x.values.reshape(-1,1)))
plt.show()

# %%
ff = pd.DataFrame(line_fitter.predict(x.values.reshape(-1,1))-y)
ff['행정동코드']=elementary_dong_new['법정동코드']

# %%
sorted_df= ff.sort_values('학교개수', ascending=False).reset_index(drop=True)

# %%
sorted_df[:10]
# Out:
#        학교개수     행정동코드
# 0  2.783332  28185106
# 1  1.586782  28260122
# 2  1.286644  28110145
# 3  0.915319  28177102
# 4  0.909957  28245110
# 5  0.863497  28200105
# 6  0.848917  28260108
# 7  0.827162  28260120
# 8  0.778788  28260104
# 9  0.769679  28177107
